# %%
from pandas import read_csv
from datetime import datetime
# load data
def parse(x):
 return datetime.strptime(x, '%Y %m %d %H')
dataset = read_csv('C:/Users/Pc/Desktop/87/der5.csv')# data5 jour pluvieux
# manually specify column names
dataset.columns = ['timestamp','Active_Energy_Delivered_Received', 'Current_Phase_Average', 'Active_Power', 'Wind_Speed', 'Weather_Temperature_Celsius', 'Weather_Relative_Humidity', 'Global_Horizontal_Radiation', 'Diffuse_Horizontal_Radiation','Wind_Direction','Weather_Daily_Rainfall','Radiation_Global_Tilted','Radiation_Diffuse_Tilted']
dataset.index.name = 'Active_Energy_Delivered_Received'
# mark all NA values with 0
dataset['Active_Energy_Delivered_Received'].fillna(0, inplace=True)
# drop the first 24 hours
dataset = dataset[24:]
# summarize first 5 rows
print(dataset.head(5))
# save to file
dataset.to_csv('Active_Energy_Delivered_Received.csv')
# Out:
#                                             timestamp  \
# Active_Energy_Delivered_Received
# 24                                2014-03-03 11:05:00
# 25                                2014-03-03 11:10:00
# 26                                2014-03-03 11:15:00
# 27                                2014-03-03 11:20:00
# 28                                2014-03-03 11:25:00
#
#                                   Active_Energy_Delivered_Received  \
# Active_Energy_Delivered_Received
# 24                                                          184390
# 25                                                          184392
# 26                                                          184393
# 27                                                          184394
# 28                                                          184396
#
#                                   Current_Phase_Average  Active_Power  \
# Active_Energy_Delivered_Received
# 24                                            20.948000     15.629032
# 25                                            21.213331     15.835300
# 26                                            21.352329     15.951934
# 27                                            21.481668     16.050867
# 28                                            21.673668     16.210566
#
#                                   Wind_Speed  Weather_Temperature_Celsius  \
# Active_Energy_Delivered_Received
# 24                                  4.741670                    30.330254
# 25                                  5.066866                    30.601486
# 26                                  5.399035                    30.722645
# 27                                  5.254183                    30.718454
# 28                                  5.747937                    30.688215
#
#                                   Weather_Relative_Humidity  \
# Active_Energy_Delivered_Received
# 24                                                21.907137
# 25                                                21.577560
# 26                                                21.591286
# 27                                                21.836151
# 28                                                21.666571
#
#                                   Global_Horizontal_Radiation  \
# Active_Energy_Delivered_Received
# 24                                                 974.969788
# 25                                                 992.245239
# 26                                                1003.662354
# 27                                                1011.313049
# 28                                                1020.032043
#
#                                   Diffuse_Horizontal_Radiation  \
# Active_Energy_Delivered_Received
# 24                                                   83.903442
# 25                                                   97.464531
# 26                                                   85.293037
# 27                                                   83.882568
# 28                                                   85.074425
#
#                                   Wind_Direction  Weather_Daily_Rainfall  \
# Active_Energy_Delivered_Received
# 24                                    103.288330                     0.0
# 25                                    120.532928                     0.0
# 26                                    108.934570                     0.0
# 27                                    109.516716                     0.0
# 28                                    129.396698                     0.0
#
#                                   Radiation_Global_Tilted  \
# Active_Energy_Delivered_Received
# 24                                            1013.421631
# 25                                            1028.838989
# 26                                            1043.658569
# 27                                            1057.003418
# 28                                            1067.344971
#
#                                   Radiation_Diffuse_Tilted
# Active_Energy_Delivered_Received
# 24                                              100.799553
# 25                                              104.236816
# 26                                              101.132484
# 27                                              100.495720
# 28                                               99.873657

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = read_csv('Active_Energy_Delivered_Received.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7, 8, 9, 10, 11, 12]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# load dataset
dataset = read_csv('Active_Energy_Delivered_Received.csv', header=0, index_col=1)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float64')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.000000   0.000000   0.809810   0.815696   0.927356   0.698603
# 2   0.000460   0.002667   0.820216   0.826461   0.952644   0.712065
# 3   0.000920   0.004000   0.825668   0.832548   0.971954   0.718079
# 4   0.001379   0.005333   0.830740   0.837711   0.965977   0.717871
# 5   0.001839   0.008000   0.838271   0.846046   0.981149   0.716370
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var4(t)   var5(t)   var6(t)   var7(t)  \
# 1   0.116741   0.780745   0.142005  0.826461  0.952644  0.712065  0.112096
# 2   0.112096   0.794596   0.165086  0.832548  0.971954  0.718079  0.112289
# 3   0.112289   0.803751   0.144370  0.837711  0.965977  0.717871  0.115741
# 4   0.115741   0.809885   0.141969  0.846046  0.981149  0.716370  0.113350
# 5   0.113350   0.816876   0.143998  0.844711  0.969655  0.723681  0.111545
#
#     var8(t)   var9(t)  var10(t)  var11(t)  var12(t)  var13(t)
# 1  0.794596  0.165086  0.960049       0.0  0.794544  0.195278
# 2  0.803751  0.144370  0.957793       0.0  0.805992  0.189391
# 3  0.809885  0.141969  0.957906       0.0  0.816302  0.188183
# 4  0.816876  0.143998  0.961774       0.0  0.824291  0.187003
# 5  0.819371  0.135768  0.957355       0.0  0.830634  0.181554

# %%
...
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24 * 12
train = values[:n_train_hours, :]
test = values[:n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (2175, 1, 18) (2175,) (2175, 1, 18) (2175,)

# %%
from keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from keras.models import Sequential
#from keras.layers import BatchNormalization, Conv1D, LSTM, Dense, Dropout, Bidirectional
import keras
import numpy as np
from keras.models import Sequential,Model
from keras.layers import Dense,Bidirectional
from nltk.tokenize import word_tokenize,sent_tokenize
from keras.layers import *
from sklearn.model_selection import cross_val_score 
import nltk
import pandas as pd
#Defining the BiLSTM Model

# design network
model = Sequential()
model.add(Bidirectional(LSTM(1000, input_shape=(train_X.shape[1], train_X.shape[2]))))
model.add(Dropout(0.0001))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/50
# 31/31 - 9s - loss: 0.1309 - val_loss: 0.0749 - 9s/epoch - 277ms/step
# Epoch 2/50
# 31/31 - 2s - loss: 0.0872 - val_loss: 0.0949 - 2s/epoch - 77ms/step
# Epoch 3/50
# 31/31 - 2s - loss: 0.0600 - val_loss: 0.0816 - 2s/epoch - 77ms/step
# Epoch 4/50
# 31/31 - 2s - loss: 0.0438 - val_loss: 0.0269 - 2s/epoch - 76ms/step
# Epoch 5/50
# 31/31 - 2s - loss: 0.0223 - val_loss: 0.0412 - 2s/epoch - 78ms/step
# Epoch 6/50
# 31/31 - 2s - loss: 0.0365 - val_loss: 0.0396 - 2s/epoch - 78ms/step
# Epoch 7/50
# 31/31 - 2s - loss: 0.0270 - val_loss: 0.0314 - 2s/epoch - 79ms/step
# Epoch 8/50
# 31/31 - 2s - loss: 0.0252 - val_loss: 0.0230 - 2s/epoch - 80ms/step
# Epoch 9/50
# 31/31 - 2s - loss: 0.0177 - val_loss: 0.0294 - 2s/epoch - 79ms/step
# Epoch 10/50
# 31/31 - 2s - loss: 0.0230 - val_loss: 0.0226 - 2s/epoch - 80ms/step
# Epoch 11/50
# 31/31 - 3s - loss: 0.0195 - val_loss: 0.0194 - 3s/epoch - 85ms/step
# Epoch 12/50
# 31/31 - 3s - loss: 0.0246 - val_loss: 0.0367 - 3s/epoch - 81ms/step
# Epoch 13/50
# 31/31 - 3s - loss: 0.0190 - val_loss: 0.0152 - 3s/epoch - 90ms/step
# Epoch 14/50
# 31/31 - 3s - loss: 0.0169 - val_loss: 0.0190 - 3s/epoch - 82ms/step
# Epoch 15/50
# 31/31 - 2s - loss: 0.0203 - val_loss: 0.0185 - 2s/epoch - 79ms/step
# Epoch 16/50
# 31/31 - 2s - loss: 0.0220 - val_loss: 0.0533 - 2s/epoch - 79ms/step
# Epoch 17/50
# 31/31 - 2s - loss: 0.0349 - val_loss: 0.0795 - 2s/epoch - 76ms/step
# Epoch 18/50
# 31/31 - 2s - loss: 0.0426 - val_loss: 0.0227 - 2s/epoch - 79ms/step
# Epoch 19/50
# 31/31 - 2s - loss: 0.0251 - val_loss: 0.0172 - 2s/epoch - 80ms/step
# Epoch 20/50
# 31/31 - 2s - loss: 0.0251 - val_loss: 0.0487 - 2s/epoch - 80ms/step
# Epoch 21/50
# 31/31 - 2s - loss: 0.0435 - val_loss: 0.0482 - 2s/epoch - 80ms/step
# Epoch 22/50
# 31/31 - 2s - loss: 0.0328 - val_loss: 0.0294 - 2s/epoch - 78ms/step
# Epoch 23/50
# 31/31 - 2s - loss: 0.0173 - val_loss: 0.0233 - 2s/epoch - 77ms/step
# Epoch 24/50
# 31/31 - 2s - loss: 0.0188 - val_loss: 0.0321 - 2s/epoch - 79ms/step
# Epoch 25/50
# 31/31 - 3s - loss: 0.0180 - val_loss: 0.0295 - 3s/epoch - 92ms/step
# Epoch 26/50
# 31/31 - 2s - loss: 0.0178 - val_loss: 0.0324 - 2s/epoch - 79ms/step
# Epoch 27/50
# 31/31 - 3s - loss: 0.0187 - val_loss: 0.0400 - 3s/epoch - 84ms/step
# Epoch 28/50
# 31/31 - 2s - loss: 0.0234 - val_loss: 0.0559 - 2s/epoch - 79ms/step
# Epoch 29/50
# 31/31 - 2s - loss: 0.0312 - val_loss: 0.0152 - 2s/epoch - 76ms/step
# Epoch 30/50
# 31/31 - 2s - loss: 0.0151 - val_loss: 0.0183 - 2s/epoch - 76ms/step
# Epoch 31/50
# 31/31 - 2s - loss: 0.0182 - val_loss: 0.0170 - 2s/epoch - 79ms/step
# Epoch 32/50
# 31/31 - 3s - loss: 0.0279 - val_loss: 0.0535 - 3s/epoch - 82ms/step
# Epoch 33/50
# 31/31 - 3s - loss: 0.0442 - val_loss: 0.0260 - 3s/epoch - 83ms/step
# Epoch 34/50
# 31/31 - 3s - loss: 0.0212 - val_loss: 0.0208 - 3s/epoch - 82ms/step
# Epoch 35/50
# 31/31 - 2s - loss: 0.0179 - val_loss: 0.0216 - 2s/epoch - 77ms/step
# Epoch 36/50
# 31/31 - 2s - loss: 0.0194 - val_loss: 0.0263 - 2s/epoch - 77ms/step
# Epoch 37/50
# 31/31 - 2s - loss: 0.0144 - val_loss: 0.0151 - 2s/epoch - 78ms/step
# Epoch 38/50
# 31/31 - 2s - loss: 0.0200 - val_loss: 0.0303 - 2s/epoch - 79ms/step
# Epoch 39/50
# 31/31 - 2s - loss: 0.0287 - val_loss: 0.0345 - 2s/epoch - 79ms/step
# Epoch 40/50
# 31/31 - 2s - loss: 0.0279 - val_loss: 0.0154 - 2s/epoch - 79ms/step
# Epoch 41/50
# 31/31 - 2s - loss: 0.0133 - val_loss: 0.0180 - 2s/epoch - 79ms/step
# Epoch 42/50
# 31/31 - 2s - loss: 0.0125 - val_loss: 0.0148 - 2s/epoch - 76ms/step
# Epoch 43/50
# 31/31 - 3s - loss: 0.0128 - val_loss: 0.0126 - 3s/epoch - 84ms/step
# Epoch 44/50
# 31/31 - 3s - loss: 0.0116 - val_loss: 0.0147 - 3s/epoch - 82ms/step
# Epoch 45/50
# 31/31 - 3s - loss: 0.0129 - val_loss: 0.0126 - 3s/epoch - 82ms/step
# Epoch 46/50
# 31/31 - 2s - loss: 0.0117 - val_loss: 0.0155 - 2s/epoch - 79ms/step
# Epoch 47/50
# 31/31 - 2s - loss: 0.0172 - val_loss: 0.0303 - 2s/epoch - 79ms/step
# Epoch 48/50
# 31/31 - 2s - loss: 0.0300 - val_loss: 0.0271 - 2s/epoch - 78ms/step
# Epoch 49/50
# 31/31 - 2s - loss: 0.0239 - val_loss: 0.0178 - 2s/epoch - 76ms/step
# Epoch 50/50
# 31/31 - 3s - loss: 0.0145 - val_loss: 0.0169 - 3s/epoch - 82ms/step
